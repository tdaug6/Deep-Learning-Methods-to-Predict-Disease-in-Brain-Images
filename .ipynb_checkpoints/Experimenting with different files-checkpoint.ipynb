# %%
import nibabel as nib
import matplotlib.pyplot as plt

img = nib.load('Brown/0026001/sfnwmrda0026001_session_1_rest_1.nii.gz')
img_data = img.get_fdata()

img_data.shape
# Out:
# (49, 58, 47, 247)

# %%
plt.imshow(img_data[25, :, :, 0], cmap='bone')
plt.axis('off')
plt.show()

# %%
img = nib.load('Brown/0026001/wmean_mrda0026001_session_1_rest_1.nii.gz')
img_data = img.get_fdata()

img_data.shape
# Out:
# (49, 58, 47)

# %%
plt.imshow(img_data[25, :, :], cmap='bone')
plt.axis('off')
plt.show()

# %%
import scipy.ndimage as ndi

plt.imshow(ndi.rotate(img_data[32, :, :], 90), cmap='bone')
plt.axis('off')
plt.show()
