# %% [markdown]
# # ADHD First Look
#
# This is my initial exploration of the data. Insights from this will likely not be very deep or meaningful.

# %% [markdown]
# ## Load dataset
#
# Use `pandas` to save the `.csv` file for analysis and manipulation
#
# Based on the first few rows, it seems like there are a lot of null values. These may be irrelevant to the analysis, but it can't be determined yet

# %%
import pandas as pd

df = pd.read_csv('allSubs_testSet_phenotypic_dx.csv', index_col='ID')

df.head()
# Out:
#         Disclaimer  Site  Gender    Age Handedness DX Secondary Dx
# ID
# 1038415        NaN     1       1  14.92          1  3           ODD  \
# 1201251        NaN     1       1  12.33          1  3           NaN
# 1245758        NaN     1       0   8.58          1  0           NaN
# 1253411        NaN     1       1   8.08          1  0           NaN
# 1419103        NaN     1       0   9.92          1  0           NaN
#
#         ADHD Measure ADHD Index Inattentive  ... Verbal IQ Performance IQ
# ID                                           ...
# 1038415            1         52          34  ...     109.0          103.0  \
# 1201251            1         49          28  ...     115.0          103.0
# 1245758            1         35          20  ...     121.0           88.0
# 1253411            1         35          19  ...     119.0          106.0
# 1419103            1         41          22  ...     124.0           76.0
#
#          Full2 IQ  Full4 IQ  QC_Rest_1  QC_Rest_2  QC_Rest_3  QC_Rest_4
# ID
# 1038415    -999.0     107.0          1        NaN        NaN        NaN  \
# 1201251    -999.0     110.0          1        NaN        NaN        NaN
# 1245758    -999.0     106.0          1        NaN        NaN        NaN
# 1253411    -999.0     114.0          1        NaN        NaN        NaN
# 1419103    -999.0     102.0          1        NaN        NaN        NaN
#
#          QC_Anatomical_1  QC_Anatomical_2
# ID
# 1038415                1              NaN
# 1201251                1              NaN
# 1245758                1              NaN
# 1253411                1              NaN
# 1419103                1              NaN
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Shape
#
# The data set contains 197 data points and 23 features. This is a fairly small dataset, so it will be important to avoid overfitting

# %%
df.shape
# Out:
# (197, 23)

# %% [markdown]
# ## Null Values
#
# This is a list of the null values. There are several columns missing nearly all of their data
#
# Most columns seem to be missing a substantial amount of information. Upon investigation, it seems that some features have matching null and real values, like they should be used together.

# %%
df.isnull().sum()
# Out:
# Disclaimer         172
# Site                 0
# Gender               0
# Age                  0
# Handedness           2
# DX                   0
# Secondary Dx       160
# ADHD Measure       120
# ADHD Index          83
# Inattentive         83
# Hyper/Impulsive     83
# Med Status         111
# IQ Measure          26
# Verbal IQ           60
# Performance IQ      60
# Full2 IQ           122
# Full4 IQ            27
# QC_Rest_1            0
# QC_Rest_2          134
# QC_Rest_3          163
# QC_Rest_4          197
# QC_Anatomical_1      0
# QC_Anatomical_2    197
# dtype: int64

# %% [markdown]
# ## Investigating features

# %% [markdown]
# ### `'Site'`
#
# There appear to be 7 sights with somewhat even distribution. These sites are based on where the evaluation was conducted

# %%
df['Site'].value_counts()
# Out:
# Site
# 1    51
# 5    41
# 6    34
# 2    26
# 4    25
# 3    11
# 7     9
# Name: count, dtype: int64

# %% [markdown]
# ### `'ADHD Measure'`
#
# This is the measuring system that was used to categorize the ADHD symptoms. It appears that this category is only measured off of one system and there are a significant number of null values

# %%
df['ADHD Measure'].value_counts()
# Out:
# ADHD Measure
# 1          51
# pending    26
# Name: count, dtype: int64

# %% [markdown]
# ## Features

# %% [markdown]
# ### Dividing Features
#
# It seems like there are three categories of features in this dataset:
#
# 1. Results: These are the results of if the patient has ADHD and their performance on the tests
#
# 2. Quality Control: These are a list of columns all starting with `'QC_'` which likely means 'Quality Control'
#
# 3. Predicting Factors: These are the remainding columns that could be used to predict if the patient has ADHD

# %%
results=df[['DX','Secondary Dx ','ADHD Measure', 'ADHD Index', 'Inattentive', 
            'Hyper/Impulsive', 'Med Status']]

qc = df[['QC_Rest_1', 'QC_Rest_2', 'QC_Rest_3', 'QC_Rest_4', 'QC_Anatomical_1', 'QC_Anatomical_2']]

features = df.drop(['DX','Secondary Dx ','ADHD Measure', 'ADHD Index', 
                    'Inattentive', 'Hyper/Impulsive', 'Med Status', 
                    'QC_Rest_1', 'QC_Rest_2', 'QC_Rest_3', 'QC_Rest_4', 
                    'QC_Anatomical_1', 'QC_Anatomical_2'], axis=1)

# %%
results.head()
# Out:
#         DX Secondary Dx  ADHD Measure ADHD Index Inattentive Hyper/Impulsive
# ID
# 1038415  3           ODD            1         52          34              18  \
# 1201251  3           NaN            1         49          28              21
# 1245758  0           NaN            1         35          20              15
# 1253411  0           NaN            1         35          19              16
# 1419103  0           NaN            1         41          22              19
#
#         Med Status
# ID
# 1038415          1
# 1201251          2
# 1245758          1
# 1253411          1
# 1419103          1

# %%
qc.head()
# Out:
#          QC_Rest_1  QC_Rest_2  QC_Rest_3  QC_Rest_4  QC_Anatomical_1
# ID
# 1038415          1        NaN        NaN        NaN                1  \
# 1201251          1        NaN        NaN        NaN                1
# 1245758          1        NaN        NaN        NaN                1
# 1253411          1        NaN        NaN        NaN                1
# 1419103          1        NaN        NaN        NaN                1
#
#          QC_Anatomical_2
# ID
# 1038415              NaN
# 1201251              NaN
# 1245758              NaN
# 1253411              NaN
# 1419103              NaN

# %%
features.head()
# Out:
#         Disclaimer  Site  Gender    Age Handedness  IQ Measure  Verbal IQ
# ID
# 1038415        NaN     1       1  14.92          1         3.0      109.0  \
# 1201251        NaN     1       1  12.33          1         3.0      115.0
# 1245758        NaN     1       0   8.58          1         3.0      121.0
# 1253411        NaN     1       1   8.08          1         3.0      119.0
# 1419103        NaN     1       0   9.92          1         3.0      124.0
#
#          Performance IQ  Full2 IQ  Full4 IQ
# ID
# 1038415           103.0    -999.0     107.0
# 1201251           103.0    -999.0     110.0
# 1245758            88.0    -999.0     106.0
# 1253411           106.0    -999.0     114.0
# 1419103            76.0    -999.0     102.0
