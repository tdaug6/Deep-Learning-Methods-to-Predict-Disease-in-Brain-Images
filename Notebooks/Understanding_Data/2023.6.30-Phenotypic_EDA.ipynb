# %% [markdown]
# # Exploratory Data Analysis Phenotypic Data
#
# This notebook investigates the contents of the phenotypic data from all sites from the ADHD-200 Competition set.

# %% [markdown]
# # Imports
#
# Access all of the packages and files that are important for running this notebook.
# This includes packages, a function, and the phenotypic file for all sites.

# %% [markdown]
# ## Packages
#
# Since this is only a exploratory data analysis, there aren't very many imports
#
# - `os` for opening files
#
# - `pandas` for dataframes
#
# - `numpy` for arrays
#
# - `matplotlib.pyplot` for plotting
#
# - `seaborn` for customizing plots

# %%
import os
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## File
#
# Import the file to perform exploratory data analysis on.
# This file is located in another folder, so it will need to be accessed from the root folder for this project.

# %% [markdown]
# ### get_base_filepath()
#
# Access the filepath for th ebase folder of the project.
# From here, any other asset of the project can be located.

# %%
def get_base_filepath():
    '''
    Access the filepath for the base folder of the project
    
    Input: None
    
    Output: The filepath to the root of the folder
    '''
    # Get current directory
    os.path.abspath(os.curdir)

    # Go up a directory level
    os.chdir('..')

    # Set baseline filepath to the project folder directory
    base_folder_filepath = os.path.abspath(os.curdir)
    return base_folder_filepath

# %% [markdown]
# ### Access file
#
# Update the filepath to include the file's location and open it as a dataframe.
# The index is the column 'ID' which is the subject ID that the row contains information about.

# %%
# The folder for the project
base_folder_filepath = get_base_filepath()

# Phenotypic data site folder
filepath = base_folder_filepath + '\\Data\\Phenotypic\\allSubs_testSet_phenotypic_dx.csv'

# Dataframe from filepath
df_pheno = pd.read_csv(filepath, index_col='ID')

# %% [markdown]
# # Exploratory Data Analysis
#
# Look at the dataframe and draw conclusions from the insights.

# %% [markdown]
# View basic properties of the unchanged dataframe.

# %%
df_pheno.shape

# %% [markdown]
# This dataframe includes 197 subjects each with 23 features.

# %%
df_pheno.head()

# %% [markdown]
# List the 23 columns

# %%
df_pheno.columns

# %% [markdown]
# ## Filter Dataframe
#
# Not all columns will be useful for making predictions.

# %% [markdown]
# ### Unnecessary
#
# These are the features that are least likely to be useful when training a machine learning model.
# A diagnosis should not depend on the quality of the scan.

# %%
drop_features = ['Disclaimer',
                 'QC_Rest_1', 'QC_Rest_2', 'QC_Rest_3', 'QC_Rest_4', 
                 'QC_Anatomical_1', 'QC_Anatomical_2']

df_pheno_filtered = df_pheno.copy()
df_pheno_filtered = df_pheno.drop(drop_features, axis=1)

# %%
df_pheno_filtered.head()

# %% [markdown]
# With this change, the number of columns has been reduced to 16.
# This will also make it easier when training since the model has less features to look at.

# %%
df_pheno_filtered.shape

# %% [markdown]
# ### Holdout
#
# Some of the data was used as a holdout for testing during the competition.
# This data is from the Brown site (Site 2) and has 'pending' for all data directly related to the diagnosis.

# %%
df_brown = df_pheno_filtered.loc[df_pheno_filtered['Site'] == 2]
df_pheno_filtered = df_pheno_filtered.drop(df_pheno_filtered.loc[df_pheno_filtered['Site'] == 2].index)
df_brown
# Out:
#        Site  Gender    Age  Handedness       DX Secondary Dx  ADHD Measure
# ID
# 26001     2       1  16.92         1.0  pending       pending      pending  \
# 26002     2       1  15.68         1.0  pending       pending      pending
# 26004     2       0  14.99         1.0  pending       pending      pending
# 26005     2       0  15.16         1.0  pending       pending      pending
# 26009     2       1  16.91         0.0  pending       pending      pending
# 26014     2       0  16.21         1.0  pending       pending      pending
# 26015     2       0  15.20         1.0  pending       pending      pending
# 26016     2       1  16.07         1.0  pending       pending      pending
# 26017     2       0  14.56         1.0  pending       pending      pending
# 26022     2       1  17.83         1.0  pending       pending      pending
# 26024     2       0  17.77         1.0  pending       pending      pending
# 26027     2       0  11.28         1.0  pending       pending      pending
# 26030     2       0  14.51         1.0  pending       pending      pending
# 26039     2       0  14.19         1.0  pending       pending      pending
# 26040     2       0  13.67         1.0  pending       pending      pending
# 26041     2       0  13.68         1.0  pending       pending      pending
# 26042     2       0  13.82         1.0  pending       pending      pending
# 26043     2       0  11.60         1.0  pending       pending      pending
# 26044     2       0   9.32         1.0  pending       pending      pending
# 26045     2       1  14.67         1.0  pending       pending      pending
# 26050     2       0   8.50         1.0  pending       pending      pending
# 26052     2       0  17.87         1.0  pending       pending      pending
# 26053     2       1  15.79         1.0  pending       pending      pending
# 26054     2       0  12.02         1.0  pending       pending      pending
# 26055     2       1  17.74         1.0  pending       pending      pending
# 26057     2       1  12.00         1.0  pending       pending      pending
#
#       ADHD Index Inattentive Hyper/Impulsive Med Status  IQ Measure
# ID
# 26001    pending     pending         pending    pending         NaN  \
# 26002    pending     pending         pending    pending         NaN
# 26004    pending     pending         pending    pending         NaN
# 26005    pending     pending         pending    pending         NaN
# 26009    pending     pending         pending    pending         NaN
# 26014    pending     pending         pending    pending         NaN
# 26015    pending     pending         pending    pending         NaN
# 26016    pending     pending         pending    pending         NaN
# 26017    pending     pending         pending    pending         NaN
# 26022    pending     pending         pending    pending         NaN
# 26024    pending     pending         pending    pending         NaN
# 26027    pending     pending         pending    pending         NaN
# 26030    pending     pending         pending    pending         NaN
# 26039    pending     pending         pending    pending         NaN
# 26040    pending     pending         pending    pending         NaN
# 26041    pending     pending         pending    pending         NaN
# 26042    pending     pending         pending    pending         NaN
# 26043    pending     pending         pending    pending         NaN
# 26044    pending     pending         pending    pending         NaN
# 26045    pending     pending         pending    pending         NaN
# 26050    pending     pending         pending    pending         NaN
# 26052    pending     pending         pending    pending         NaN
# 26053    pending     pending         pending    pending         NaN
# 26054    pending     pending         pending    pending         NaN
# 26055    pending     pending         pending    pending         NaN
# 26057    pending     pending         pending    pending         NaN
#
#        Verbal IQ  Performance IQ  Full2 IQ  Full4 IQ
# ID
# 26001      133.0           104.0       NaN     120.0
# 26002      106.0           106.0       NaN     107.0
# 26004      119.0           123.0       NaN     125.0
# 26005      116.0           131.0       NaN     126.0
# 26009      113.0            81.0       NaN      97.0
# 26014      101.0           102.0       NaN     102.0
# 26015      127.0            98.0       NaN     113.0
# 26016      120.0            96.0       NaN     109.0
# 26017       95.0            87.0       NaN      89.0
# 26022      105.0           111.0       NaN     109.0
# 26024       89.0            83.0       NaN      85.0
# 26027      108.0           103.0       NaN     106.0
# 26030      121.0           119.0       NaN     123.0
# 26039      125.0           117.0       NaN     124.0
# 26040      111.0            93.0       NaN     102.0
# 26041      129.0           120.0       NaN     128.0
# 26042      106.0           110.0       NaN     109.0
# 26043      125.0           127.0       NaN     129.0
# 26044      119.0            93.0       NaN     107.0
# 26045      109.0           109.0       NaN     111.0
# 26050      121.0           116.0       NaN     121.0
# 26052      111.0           109.0       NaN     112.0
# 26053      123.0           111.0       NaN     120.0
# 26054      136.0           109.0       NaN     125.0
# 26055      109.0           119.0       NaN     116.0
# 26057      114.0           110.0       NaN     114.0

# %% [markdown]
# There are 26 subjects at the Brown site.

# %%
df_brown.shape

# %% [markdown]
# When the Brown subjects are removed from the dataframe, there are 171 subjects remaining.

# %%
df_pheno_filtered.shape

# %% [markdown]
# ### Targets
#
# These columns directly relate to the diagnosis.
# In the Brown site, these columns are withheld and replaced with 'pending'

# %%
targets_features = ['DX', 'Secondary Dx ', 
                    'ADHD Measure', 'ADHD Index', 'Inattentive', 
                    'Hyper/Impulsive', 'Med Status']

df_targets = df_pheno_filtered[targets_features]
df_brown_targets = df_brown[targets_features]
df_pheno_filtered = df_pheno_filtered.drop(targets_features, axis=1)

# %%
df_targets.head()

# %%
df_pheno_filtered.head()

# %% [markdown]
# ## Null values
#
# Look at every column and find the null values or imputed null values (-999)

# %% [markdown]
# ### Main Dataframe
#
# Focuses on the main dataframe.

# %%
df_pheno_filtered.loc[df_pheno_filtered['Handedness'] > 0, 'Handedness'] = 1
df_pheno_filtered.loc[df_pheno_filtered['Handedness'] < 0, 'Handedness'] = 0
# Out:
# ID
# 1038415    1.0
# 1201251    1.0
# 1245758    1.0
# 1253411    1.0
# 1419103    1.0
#           ...
# 25008      1.0
# 25009      1.0
# 25012      1.0
# 25013      1.0
# 25014      1.0
# Name: Handedness, Length: 171, dtype: float64

# %%
null_values = dict()
numeric_cols = ['Gender', 'Age', 'IQ Measure', 'Handedness',
                'Verbal IQ', 'Performance IQ', 'Full2 IQ', 'Full4 IQ']

for col in numeric_cols:
    null_values[col] = (df_pheno_filtered[col].isnull().sum(), df_pheno_filtered[col].min())

df_null_values = pd.DataFrame(data=null_values, index=['Null_count', 'Min_value'])
df_null_values.head()
# Out:
#             Gender   Age  IQ Measure  Handedness  Verbal IQ  Performance IQ
# Null_count       0  0.00         0.0         2.0       60.0            60.0  \
# Min_value        0  7.26         1.0         0.0       80.0            67.0
#
#             Full2 IQ  Full4 IQ
# Null_count      96.0      27.0
# Min_value     -999.0      77.0

# %% [markdown]
# The 60 points where Perforamnce IQ is null are the same 60 points where Verbal IQ is null.

# %%
df_pheno_filtered[df_pheno_filtered['Performance IQ'].isnull()]
# Out:
#        Site  Gender    Age  Handedness  IQ Measure  Verbal IQ  Performance IQ
# ID
# 27000     4       0  20.90         1.0         5.0        NaN             NaN  \
# 27003     4       1  17.54         0.0         5.0        NaN             NaN
# 27004     4       1  14.24         0.0         5.0        NaN             NaN
# 27005     4       0  18.65         0.0         5.0        NaN             NaN
# 27007     4       1  16.92         1.0         5.0        NaN             NaN
# 27008     4       1  25.04         1.0         5.0        NaN             NaN
# 27010     4       0  16.45         1.0         5.0        NaN             NaN
# 27011     4       1  20.82         1.0         5.0        NaN             NaN
# 27012     4       0  14.05         NaN         5.0        NaN             NaN
# 27015     4       0  20.34         1.0         5.0        NaN             NaN
# 27016     4       0  20.31         1.0         5.0        NaN             NaN
# 27017     4       0  26.31         1.0         5.0        NaN             NaN
# 27018     4       1  19.08         NaN         5.0        NaN             NaN
# 27020     4       0  23.59         1.0         5.0        NaN             NaN
# 27021     4       0  20.02         1.0         5.0        NaN             NaN
# 27022     4       0  16.65         1.0         5.0        NaN             NaN
# 27023     4       1  18.08         1.0         5.0        NaN             NaN
# 27024     4       0  20.67         1.0         5.0        NaN             NaN
# 27025     4       0  21.53         1.0         5.0        NaN             NaN
# 27026     4       0  20.55         1.0         5.0        NaN             NaN
# 27028     4       1  14.94         1.0         5.0        NaN             NaN
# 27034     4       1  13.35         1.0         5.0        NaN             NaN
# 27037     4       1  17.74         1.0         5.0        NaN             NaN
# 27040     4       1  17.18         1.0         5.0        NaN             NaN
# 27042     4       1  16.72         1.0         5.0        NaN             NaN
# 21008     5       1  11.28         1.0         2.0        NaN             NaN
# 23000     6       0  10.42         1.0         2.0        NaN             NaN
# 23001     6       1   9.33         1.0         2.0        NaN             NaN
# 23002     6       1  10.67         1.0         2.0        NaN             NaN
# 23003     6       1   7.67         1.0         2.0        NaN             NaN
# 23004     6       1   9.33         1.0         2.0        NaN             NaN
# 23005     6       1  11.75         1.0         2.0        NaN             NaN
# 23006     6       0   9.25         1.0         2.0        NaN             NaN
# 23007     6       1  11.08         1.0         2.0        NaN             NaN
# 23008     6       1   9.17         1.0         2.0        NaN             NaN
# 23010     6       0   7.67         1.0         2.0        NaN             NaN
# 23011     6       1   8.92         1.0         2.0        NaN             NaN
# 23012     6       0  11.33         1.0         2.0        NaN             NaN
# 23013     6       1  10.58         1.0         2.0        NaN             NaN
# 23016     6       0  10.25         1.0         2.0        NaN             NaN
# 23017     6       0  12.50         1.0         2.0        NaN             NaN
# 23018     6       0   9.50         1.0         2.0        NaN             NaN
# 23019     6       0   8.08         1.0         2.0        NaN             NaN
# 23020     6       1  11.00         1.0         2.0        NaN             NaN
# 23024     6       0   9.58         1.0         2.0        NaN             NaN
# 23025     6       0   8.33         1.0         2.0        NaN             NaN
# 23026     6       0   8.33         1.0         2.0        NaN             NaN
# 23027     6       1  11.58         1.0         2.0        NaN             NaN
# 23028     6       0   9.92         1.0         2.0        NaN             NaN
# 23030     6       1   8.50         1.0         2.0        NaN             NaN
# 23031     6       1  11.92         1.0         2.0        NaN             NaN
# 23033     6       0   8.50         1.0         2.0        NaN             NaN
# 23035     6       1   9.75         1.0         2.0        NaN             NaN
# 23036     6       0   9.75         1.0         2.0        NaN             NaN
# 23037     6       1   9.42         1.0         2.0        NaN             NaN
# 23038     6       1   9.33         1.0         2.0        NaN             NaN
# 23039     6       1  11.17         1.0         2.0        NaN             NaN
# 23040     6       0   7.50         1.0         2.0        NaN             NaN
# 23041     6       0   9.92         1.0         2.0        NaN             NaN
# 23042     6       0   8.08         1.0         2.0        NaN             NaN
#
#        Full2 IQ  Full4 IQ
# ID
# 27000      91.0       NaN
# 27003     106.0       NaN
# 27004      91.0       NaN
# 27005      87.0       NaN
# 27007      91.0       NaN
# 27008      78.0       NaN
# 27010     116.0       NaN
# 27011     128.0       NaN
# 27012       NaN       NaN
# 27015     106.0       NaN
# 27016     128.0       NaN
# 27017     103.0       NaN
# 27018     113.0       NaN
# 27020      97.0       NaN
# 27021     109.0       NaN
# 27022     109.0       NaN
# 27023      81.0       NaN
# 27024     100.0       NaN
# 27025     106.0       NaN
# 27026      78.0       NaN
# 27028      82.0       NaN
# 27034      97.0       NaN
# 27037      78.0       NaN
# 27040      84.0       NaN
# 27042      75.0       NaN
# 21008       NaN       NaN
# 23000       NaN     104.0
# 23001       NaN      96.0
# 23002       NaN     136.0
# 23003       NaN     126.0
# 23004       NaN     103.8
# 23005       NaN     104.0
# 23006       NaN     114.0
# 23007       NaN     112.0
# 23008       NaN     112.0
# 23010       NaN     118.0
# 23011       NaN     104.0
# 23012       NaN     120.0
# 23013       NaN      94.0
# 23016       NaN     143.7
# 23017       NaN     112.0
# 23018       NaN     100.0
# 23019       NaN     132.0
# 23020       NaN     122.0
# 23024       NaN      98.0
# 23025       NaN      98.0
# 23026       NaN     106.0
# 23027       NaN     100.0
# 23028       NaN     117.1
# 23030       NaN     120.0
# 23031       NaN     126.0
# 23033       NaN     120.0
# 23035       NaN     105.7
# 23036       NaN     128.0
# 23037       NaN     108.0
# 23038       NaN     124.0
# 23039       NaN     114.0
# 23040       NaN     126.0
# 23041       NaN     128.5
# 23042       NaN      98.0

# %%
len(df_pheno_filtered[df_pheno_filtered['Performance IQ'].isnull()])
# Out:
# 60

# %% [markdown]
# The points where Full4 IQ are null are the non-null values for Full2 IQ

# %%
df_pheno_filtered[df_pheno_filtered['Full4 IQ'].isnull()]
# Out:
#        Site  Gender    Age  Handedness  IQ Measure  Verbal IQ  Performance IQ
# ID
# 27000     4       0  20.90         1.0         5.0        NaN             NaN  \
# 27003     4       1  17.54         0.0         5.0        NaN             NaN
# 27004     4       1  14.24         0.0         5.0        NaN             NaN
# 27005     4       0  18.65         0.0         5.0        NaN             NaN
# 27007     4       1  16.92         1.0         5.0        NaN             NaN
# 27008     4       1  25.04         1.0         5.0        NaN             NaN
# 27010     4       0  16.45         1.0         5.0        NaN             NaN
# 27011     4       1  20.82         1.0         5.0        NaN             NaN
# 27012     4       0  14.05         NaN         5.0        NaN             NaN
# 27015     4       0  20.34         1.0         5.0        NaN             NaN
# 27016     4       0  20.31         1.0         5.0        NaN             NaN
# 27017     4       0  26.31         1.0         5.0        NaN             NaN
# 27018     4       1  19.08         NaN         5.0        NaN             NaN
# 27020     4       0  23.59         1.0         5.0        NaN             NaN
# 27021     4       0  20.02         1.0         5.0        NaN             NaN
# 27022     4       0  16.65         1.0         5.0        NaN             NaN
# 27023     4       1  18.08         1.0         5.0        NaN             NaN
# 27024     4       0  20.67         1.0         5.0        NaN             NaN
# 27025     4       0  21.53         1.0         5.0        NaN             NaN
# 27026     4       0  20.55         1.0         5.0        NaN             NaN
# 27028     4       1  14.94         1.0         5.0        NaN             NaN
# 27034     4       1  13.35         1.0         5.0        NaN             NaN
# 27037     4       1  17.74         1.0         5.0        NaN             NaN
# 27040     4       1  17.18         1.0         5.0        NaN             NaN
# 27042     4       1  16.72         1.0         5.0        NaN             NaN
# 21008     5       1  11.28         1.0         2.0        NaN             NaN
# 21030     5       1  10.74         1.0         2.0      110.0           100.0
#
#        Full2 IQ  Full4 IQ
# ID
# 27000      91.0       NaN
# 27003     106.0       NaN
# 27004      91.0       NaN
# 27005      87.0       NaN
# 27007      91.0       NaN
# 27008      78.0       NaN
# 27010     116.0       NaN
# 27011     128.0       NaN
# 27012       NaN       NaN
# 27015     106.0       NaN
# 27016     128.0       NaN
# 27017     103.0       NaN
# 27018     113.0       NaN
# 27020      97.0       NaN
# 27021     109.0       NaN
# 27022     109.0       NaN
# 27023      81.0       NaN
# 27024     100.0       NaN
# 27025     106.0       NaN
# 27026      78.0       NaN
# 27028      82.0       NaN
# 27034      97.0       NaN
# 27037      78.0       NaN
# 27040      84.0       NaN
# 27042      75.0       NaN
# 21008       NaN       NaN
# 21030       NaN       NaN

# %%
df_targets['Secondary Dx '].isnull().sum()

# %%
df_targets['Secondary Dx '] = df_targets['Secondary Dx '].fillna('none')

# %%
plt.figure(figsize=(15,7))
sns.heatmap(df_pheno_filtered.corr(), annot=True)
# Out:
# <Axes: >

# %%
features = ['Gender', 'Age', 'Handedness', 'Verbal IQ', 'Performance IQ', 'IQ', 'DX']

plt.figure(figsize=(7,5))
sns.heatmap(df_pheno_filtered[features].corr(), annot=True)
# Out:
# <Axes: >

# %%
df_pheno_filtered['Gender'].value_counts()

# %%
df_pheno_filtered.groupby('DX')['Gender'].median()

# %%
df_pheno_filtered.groupby('Site')['Gender'].median()
