# %%
import pandas as pd
import numpy as np

# %%
import os

os.path.abspath(os.curdir)
os.chdir('..')
filepath = os.path.abspath(os.curdir)
filepath_img = filepath + '\\Data\\Preprocessed_data\\Brown\\0026001\\sfnwmrda0026001_session_1_rest_1.nii.gz'
print(filepath_img)
# Out:
# C:\Users\taylo\School Work\Co-ops\Protege\Deep-Learning-Methods-to-Predict-Disease-in-Brain-Images\Data\Preprocessed_data\Brown\0026001\sfnwmrda0026001_session_1_rest_1.nii.gz

# %%
import nibabel as nib
import matplotlib.pyplot as plt

img = nib.load(filepath_img)
img_data = img.get_fdata()

img_data.shape
# Out:
# (49, 58, 47, 247)

# %%
plt.imshow(img_data[25, :, :, 0], cmap='bone')
plt.axis('off')
plt.show()

# %%
filepath_anat = filepath + '\\Data\\Preprocessed_data\\Brown\\0026001\\fc_snwmrda0026001_session_1_rest_1.nii.gz'

# %%
img_fc = nib.load(filepath_anat)
img_data_fc = img_fc.get_fdata()

img_data_fc.shape
# Out:
# (49, 58, 47, 1, 10)

# %%
plt.imshow(img_data_fc[25, :, :, :, 0], cmap='bone')
plt.axis('off')
plt.show()

# %%
plt.imshow(img_data_fc[25, :, :, :, 1], cmap='bone')
plt.axis('off')
plt.show()

# %%
plt.imshow(img_data_fc[25, :, :, :, 2], cmap='bone')
plt.axis('off')
plt.show()

# %%
plt.imshow(img_data_fc[25, :, :, :, 3], cmap='bone')
plt.axis('off')
plt.show()

# %%
filepath_mean = filepath + '\\Data\\Preprocessed_data\\Brown\\0026001\\wmean_mrda0026001_session_1_rest_1.nii.gz'

# %%
img_m = nib.load(filepath_mean)
img_data_m = img_m.get_fdata()

img_data_m.shape
# Out:
# (49, 58, 47)

# %%
plt.imshow(img_data_m[25, :, :], cmap='bone')
plt.axis('off')
plt.show()

# %%
import scipy.ndimage as ndi

plt.imshow(ndi.rotate(img_data_m[32, :, :], 90), cmap='bone')
plt.axis('off')
plt.show()
