# %% [markdown]
# # Exploratory Data Analysis Phenotypic Data
#
# This notebook investigates the contents of the phenotypic data from all sites from the ADHD-200 Competition set.

# %% [markdown]
# ## Imports
#
# Since this is only a exploratory data analysis, there aren't very many imports
#
# - `os` for opening files
#
# - `pandas` for dataframes
#
# - `numpy` for arrays
#
# - `matplotlib.pyplot` for plotting
#
# - `seaborn` for customizing plots

# %%
import os
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### get_base_filepath()
#
# Access the filepath for th ebase folder of the project.
# From here, any other asset of the project can be located.

# %%
def get_base_filepath():
    '''
    Access the filepath for the base folder of the project
    
    Input: None
    
    Output: The filepath to the root of the folder
    '''
    # Get current directory
    os.path.abspath(os.curdir)

    # Go up a directory level
    os.chdir('..')

    # Set baseline filepath to the project folder directory
    base_folder_filepath = os.path.abspath(os.curdir)
    return base_folder_filepath

# %%
# The folder for the project
base_folder_filepath = get_base_filepath()

# Phenotypic data site folder
filepath = base_folder_filepath + '\\Data\\Phenotypic\\allSubs_testSet_phenotypic_dx.csv'

# Dataframe from filepath
df_pheno = pd.read_csv(filepath, index_col='ID')

# %%
df_pheno.shape
# Out:
# (197, 23)

# %%
df_pheno.head()
# Out:
#         Disclaimer  Site  Gender    Age Handedness DX Secondary Dx
# ID
# 1038415        NaN     1       1  14.92          1  3           ODD  \
# 1201251        NaN     1       1  12.33          1  3           NaN
# 1245758        NaN     1       0   8.58          1  0           NaN
# 1253411        NaN     1       1   8.08          1  0           NaN
# 1419103        NaN     1       0   9.92          1  0           NaN
#
#         ADHD Measure ADHD Index Inattentive  ... Verbal IQ Performance IQ
# ID                                           ...
# 1038415            1         52          34  ...     109.0          103.0  \
# 1201251            1         49          28  ...     115.0          103.0
# 1245758            1         35          20  ...     121.0           88.0
# 1253411            1         35          19  ...     119.0          106.0
# 1419103            1         41          22  ...     124.0           76.0
#
#          Full2 IQ  Full4 IQ  QC_Rest_1  QC_Rest_2  QC_Rest_3  QC_Rest_4
# ID
# 1038415    -999.0     107.0          1        NaN        NaN        NaN  \
# 1201251    -999.0     110.0          1        NaN        NaN        NaN
# 1245758    -999.0     106.0          1        NaN        NaN        NaN
# 1253411    -999.0     114.0          1        NaN        NaN        NaN
# 1419103    -999.0     102.0          1        NaN        NaN        NaN
#
#          QC_Anatomical_1  QC_Anatomical_2
# ID
# 1038415                1              NaN
# 1201251                1              NaN
# 1245758                1              NaN
# 1253411                1              NaN
# 1419103                1              NaN
#
# [5 rows x 23 columns]

# %%
df_pheno.columns
# Out:
# Index(['Disclaimer', 'Site', 'Gender', 'Age', 'Handedness', 'DX',
#        'Secondary Dx ', 'ADHD Measure', 'ADHD Index', 'Inattentive',
#        'Hyper/Impulsive', 'Med Status', 'IQ Measure', 'Verbal IQ',
#        'Performance IQ', 'Full2 IQ', 'Full4 IQ', 'QC_Rest_1', 'QC_Rest_2',
#        'QC_Rest_3', 'QC_Rest_4', 'QC_Anatomical_1', 'QC_Anatomical_2'],
#       dtype='object')

# %%
drop_features = ['Disclaimer',
                 'QC_Rest_1', 'QC_Rest_2', 'QC_Rest_3', 'QC_Rest_4', 
                 'QC_Anatomical_1', 'QC_Anatomical_2']

df_pheno_filtered = df_pheno.copy()
df_pheno_filtered = df_pheno.drop(drop_features, axis=1)

# %%
df_pheno_filtered.head()
# Out:
#          Site  Gender    Age Handedness DX Secondary Dx  ADHD Measure
# ID
# 1038415     1       1  14.92          1  3           ODD            1  \
# 1201251     1       1  12.33          1  3           NaN            1
# 1245758     1       0   8.58          1  0           NaN            1
# 1253411     1       1   8.08          1  0           NaN            1
# 1419103     1       0   9.92          1  0           NaN            1
#
#         ADHD Index Inattentive Hyper/Impulsive Med Status  IQ Measure
# ID
# 1038415         52          34              18          1         3.0  \
# 1201251         49          28              21          2         3.0
# 1245758         35          20              15          1         3.0
# 1253411         35          19              16          1         3.0
# 1419103         41          22              19          1         3.0
#
#          Verbal IQ  Performance IQ  Full2 IQ  Full4 IQ
# ID
# 1038415      109.0           103.0    -999.0     107.0
# 1201251      115.0           103.0    -999.0     110.0
# 1245758      121.0            88.0    -999.0     106.0
# 1253411      119.0           106.0    -999.0     114.0
# 1419103      124.0            76.0    -999.0     102.0

# %%
targets_features = ['DX', 'Secondary Dx ', 
                    'ADHD Measure', 'ADHD Index', 'Inattentive', 
                    'Hyper/Impulsive', 'Med Status']

df_targets = df_pheno_filtered[targets_features]
df_pheno_filtered = df_pheno_filtered.drop(targets_features, axis=1)

# %%
df_targets.head()
# Out:
#         DX Secondary Dx  ADHD Measure ADHD Index Inattentive Hyper/Impulsive
# ID
# 1038415  3           ODD            1         52          34              18  \
# 1201251  3           NaN            1         49          28              21
# 1245758  0           NaN            1         35          20              15
# 1253411  0           NaN            1         35          19              16
# 1419103  0           NaN            1         41          22              19
#
#         Med Status
# ID
# 1038415          1
# 1201251          2
# 1245758          1
# 1253411          1
# 1419103          1

# %%
df_pheno_filtered.head()
# Out:
#          Site  Gender    Age Handedness  IQ Measure  Verbal IQ
# ID
# 1038415     1       1  14.92          1         3.0      109.0  \
# 1201251     1       1  12.33          1         3.0      115.0
# 1245758     1       0   8.58          1         3.0      121.0
# 1253411     1       1   8.08          1         3.0      119.0
# 1419103     1       0   9.92          1         3.0      124.0
#
#          Performance IQ  Full2 IQ  Full4 IQ
# ID
# 1038415           103.0    -999.0     107.0
# 1201251           103.0    -999.0     110.0
# 1245758            88.0    -999.0     106.0
# 1253411           106.0    -999.0     114.0
# 1419103            76.0    -999.0     102.0

# %%
df_pheno_filtered['Gender'].isnull().sum()
# Out:
# 0

# %%
min(df_pheno_filtered['Gender'])
# Out:
# 0

# %%
df_pheno_filtered['Age'].isnull().sum()
# Out:
# 0

# %%
min(df_pheno_filtered['Age'])
# Out:
# 7.26

# %%
df_pheno_filtered['Handedness'].isnull().sum()
# Out:
# 2

# %%
df_pheno_filtered[df_pheno_filtered['Handedness'] == 'L']
# Out:
#          Site  Gender   Age Handedness  IQ Measure  Verbal IQ  Performance IQ
# ID
# 4125514     1       1  9.17          L         3.0      136.0           100.0  \
#
#          Full2 IQ  Full4 IQ
# ID
# 4125514    -999.0     121.0

# %%
df_pheno_filtered.loc[df_pheno_filtered['Handedness'] == 'L', 'Handedness'] = 0

# df_pheno_filtered[df_pheno_filtered['Handedness'] == 'L']['Handedness'] = 0

# %%
df_pheno_filtered['IQ Measure'].isnull().sum()
# Out:
# 26

# %%
min(df_pheno_filtered['IQ Measure'])
# Out:
# 1.0

# %%
df_pheno_filtered['Verbal IQ'].isnull().sum()
# Out:
# 60

# %%
min(df_pheno_filtered['Verbal IQ'])
# Out:
# 80.0

# %%
df_pheno_filtered['Performance IQ'].isnull().sum()
# Out:
# 60

# %%
min(df_pheno_filtered['Performance IQ'])
# Out:
# 67.0

# %%
df_pheno_filtered['Full2 IQ'].isnull().sum()
# Out:
# 122

# %%
min(df_pheno_filtered['Full2 IQ'])
# Out:
# -999.0

# %%
df_pheno_filtered[df_pheno_filtered['Full2 IQ'] == -999]
# Out:
#          Site  Gender    Age Handedness  IQ Measure  Verbal IQ
# ID
# 1038415     1       1  14.92          1         3.0      109.0  \
# 1201251     1       1  12.33          1         3.0      115.0
# 1245758     1       0   8.58          1         3.0      121.0
# 1253411     1       1   8.08          1         3.0      119.0
# 1419103     1       0   9.92          1         3.0      124.0
# 1517058     1       1   9.75          1         3.0      141.0
# 1581470     1       1   8.83          1         3.0      111.0
# 1784368     1       1   8.92          1         3.0      136.0
# 1849382     1       1  11.67          1         3.0      140.0
# 1854691     1       0   8.83          1         3.0      117.0
# 1883688     1       0   9.08          1         3.0      112.0
# 1951511     1       0  11.92          1         3.0      126.0
# 1985430     1       0  11.92          1         3.0      146.0
# 2024999     1       1  10.33          1         3.0      117.0
# 2051479     1       0  13.75          1         3.0      109.0
# 2101067     1       0  15.17          1         3.0      117.0
# 2275786     1       1   9.50          1         3.0      112.0
# 2342030     1       0  10.17          1         3.0      111.0
# 2380326     1       0   9.58          1         3.0      103.0
# 2380967     1       1  10.00          1         3.0      109.0
# 2411995     1       1   9.75          1         3.0      107.0
# 2443191     1       1   8.92          1         3.0       99.0
# 2488729     1       0  13.75          1         3.0      113.0
# 2505328     1       0   8.83          1         3.0       83.0
# 2511886     1       1   8.33          1         3.0      133.0
# 2528407     1       1   8.92          1         3.0      141.0
# 2591713     1       1  10.00          1         3.0      134.0
# 2599965     1       1  14.00          1         3.0      101.0
# 2628237     1       0  13.00          1         3.0       90.0
# 2872641     1       0   8.50          1         3.0      109.0
# 3107623     1       0  11.92          1         3.0      121.0
# 3124419     1       1   8.75          1         3.0      128.0
# 3169448     1       1  11.00          1         3.0      104.0
# 3313497     1       1   9.33          1         3.0      111.0
# 3320367     1       1  10.67          1         3.0      126.0
# 3348989     1       0   8.33          1         3.0      126.0
# 3378296     1       1   9.83          1         3.0      141.0
# 3407871     1       1  13.33          1         3.0      100.0
# 3504058     1       1  13.17          1         3.0      115.0
# 3520880     1       1   9.83          1         3.0      140.0
# 3559087     1       1  12.58          1         3.0      108.0
# 3605062     1       0   8.58          1         3.0      130.0
# 3767334     1       1   8.33          1         3.0      112.0
# 3834703     1       1  12.92          1         3.0      112.0
# 4125514     1       1   9.17          0         3.0      136.0
# 6550938     1       1  11.50          1         3.0      146.0
# 7591533     1       1  12.42          1         3.0       97.0
# 7947495     1       0   9.17          1         3.0      113.0
# 8463326     1       0  12.67          1         3.0      108.0
# 9190596     1       1  12.50          1         3.0      134.0
# 9744150     1       1   9.50          1         3.0      117.0
#
#          Performance IQ  Full2 IQ  Full4 IQ
# ID
# 1038415           103.0    -999.0     107.0
# 1201251           103.0    -999.0     110.0
# 1245758            88.0    -999.0     106.0
# 1253411           106.0    -999.0     114.0
# 1419103            76.0    -999.0     102.0
# 1517058           138.0    -999.0     144.0
# 1581470           123.0    -999.0     118.0
# 1784368            89.0    -999.0     116.0
# 1849382           114.0    -999.0     131.0
# 1854691           108.0    -999.0     114.0
# 1883688            83.0    -999.0      98.0
# 1951511           111.0    -999.0     121.0
# 1985430           124.0    -999.0     140.0
# 2024999            98.0    -999.0     109.0
# 2051479           104.0    -999.0     108.0
# 2101067            98.0    -999.0     109.0
# 2275786           108.0    -999.0     111.0
# 2342030           120.0    -999.0     117.0
# 2380326           100.0    -999.0     102.0
# 2380967           115.0    -999.0     113.0
# 2411995            94.0    -999.0     101.0
# 2443191            71.0    -999.0      84.0
# 2488729           103.0    -999.0     109.0
# 2505328            85.0    -999.0      82.0
# 2511886           115.0    -999.0     128.0
# 2528407           100.0    -999.0     124.0
# 2591713           115.0    -999.0     128.0
# 2599965            94.0    -999.0      98.0
# 2628237           106.0    -999.0      97.0
# 2872641           120.0    -999.0     116.0
# 3107623           114.0    -999.0     120.0
# 3124419            85.0    -999.0     109.0
# 3169448           111.0    -999.0     108.0
# 3313497           109.0    -999.0     111.0
# 3320367           109.0    -999.0     120.0
# 3348989            97.0    -999.0     114.0
# 3378296           112.0    -999.0     131.0
# 3407871            98.0    -999.0      99.0
# 3504058           100.0    -999.0     109.0
# 3520880           135.0    -999.0     142.0
# 3559087           104.0    -999.0     107.0
# 3605062           100.0    -999.0     118.0
# 3767334           104.0    -999.0     109.0
# 3834703           101.0    -999.0     108.0
# 4125514           100.0    -999.0     121.0
# 6550938           112.0    -999.0     134.0
# 7591533            76.0    -999.0      86.0
# 7947495           111.0    -999.0     113.0
# 8463326            94.0    -999.0     102.0
# 9190596           114.0    -999.0     128.0
# 9744150           104.0    -999.0     113.0

# %%
df_pheno_filtered['Full2 IQ'].isnull().sum() + len(df_pheno_filtered[df_pheno_filtered['Full2 IQ'] == -999])
# Out:
# 173

# %%
df_pheno_filtered['Full4 IQ'].isnull().sum()
# Out:
# 27

# %%
min(df_pheno_filtered['Full4 IQ'])
# Out:
# 77.0

# %%
df_targets['Med Status'].isnull().sum()
# Out:
# 111

# %%
min(df_pheno_filtered['Med Status'])

# %%
df_targets[df_targets['Med Status'] == -999]

# %%
df_targets['Secondary Dx '] = df_targets['Secondary Dx '].fillna('none')

# %%
df_targets['DX'].isnull().sum()
